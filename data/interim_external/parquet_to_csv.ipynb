# %% [markdown]
# Parquet Datei zu CSV konvertieren:

# %%
import pandas as pd
df = pd.read_parquet("scraped_workwise_dynamic_unified.parquet") # Datei
df.to_csv("scraped_workwise_dynamic_unified.csv", index=False)

# %%
df = pd.read_parquet("resume_structured_unified.parquet") # Datei
df.to_csv("resume_structured_unified.csv", index=False)
